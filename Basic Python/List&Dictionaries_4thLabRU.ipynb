# %% [markdown]
# # Lists

# %% [markdown]
# Lists
# A list is an ordered, mutable (changeable) collection of elements. Lists can contain items of different data types, but typically all items are of the same type for practical use.
#
# Key Characteristics:
# Ordered: The order of elements is maintained.
# Mutable: You can add, remove, or change items.
# Can contain duplicates.

# %% [markdown]
# Key Differences Between Lists and Dictionaries:
# Feature	List	Dictionary
# Structure	Ordered collection of items	Key-value pairs
# Access	Access by index (list[0])	Access by key (dict[key])
# Mutability	Mutable	Mutable
# Duplicates	Allows duplicate values	Keys must be unique

# %%
# Create a list
fruits = ["apple", "banana", "cherry"]

# %%
# Access elements
print(fruits[0])  # Output: apple
# Out:
# apple

# %%
# Modify elements
fruits[1] = "blueberry"
print(fruits[1])
# Out:
# blueberry

# %%
# Add elements
fruits.append("orange")  # Add at the end
fruits.insert(6, "grape")  # Insert at a specific position
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'grape', 'orange', 'grape', 'grape', 'grape', 'grape', 'grape', 'grape', 'orange', 'orange', 'orange', 'orange', 'orange']

# %%
# Remove elements
fruits.remove("apple")  # Remove by value
popped_item = fruits.pop()  # Remove last element
del fruits[0]  # Remove by index

# %%
# Loop through a list
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
# List comprehension
squared_numbers = [x**2 for x in range(5)]  # Output: [0, 1, 4, 9, 16]

# %% [markdown]
# # Dictionaries

# %% [markdown]
# Dictionaries
# A dictionary is an unordered, mutable collection of key-value pairs. Each key in a dictionary must be unique, and values can be of any type.
#
# Key Characteristics:
# Unordered (in Python versions < 3.7); as of Python 3.7+, dictionaries maintain insertion order.
# Mutable: You can add, remove, or change items.
# Keys must be immutable types (e.g., strings, numbers, tuples).
# Syntax:
#
# my_dict = {"key1": "value1", "key2": "value2"}

# %%
# Create a dictionary
person = {"name": "Alice", "age": 25, "city": "New York"}

# Access values
print(person["name"])  # Output: Alice

# Modify values
person["age"] = 30

# Add new key-value pairs
person["profession"] = "Engineer"

# Remove key-value pairs
del person["city"]

# Loop through a dictionary
for key in person:
    print(key, person[key])

# Access keys, values, and items
print(person.keys())    # Output: dict_keys(['name', 'age', 'profession'])
print(person.values())  # Output: dict_values(['Alice', 30, 'Engineer'])
print(person.items())   # Output: dict_items([('name', 'Alice'), ('age', 30), ('profession', 'Engineer')])

# Check for a key
if "name" in person:
    print("Name exists in the dictionary.")

# %% [markdown]
# #  Perform Basic Operations on List and Dictionary Elements

# %% [markdown]
# ## **List**

# %%
#Concatenation:
list1 = [1, 2, 3]
list2 = [4, 5, 6]
combinedList = list1 + list2
print(combinedList)  # Output: [1, 2, 3, 4, 5, 6]
#Repetition:
my_list = [1, 2]
repeated = my_list * 3
print(repeated)  # Output: [1, 2, 1, 2, 1, 2]
#Membership Testing:
my_list = [10, 20, 30]
print(20 in my_list)  # Output: True
print(40 in my_list)  # Output: False
#Sorting:
my_list = [50, 10, 30, 20, 40]
my_list.sort()
print(my_list)  # Output: [10, 20, 30, 40, 50]
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 1, 2, 1, 2]
# True
# False
# [10, 20, 30, 40, 50]

# %% [markdown]
# ## Dictonary

# %%
#Merge Dictionaries
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
dict1.update(dict2)
print(dict1)  # Output: {'a': 1, 'b': 3, 'c': 4}
#Iterate Over Keys and Values
my_dict = {'name': 'Alice', 'age': 25}
for key, value in my_dict.items():
    print(f"{key}: {value}")
# Output:
# name: Alice
# age: 25
#Membership Checking
my_dict = {'name': 'Alice', 'age': 25}
print('name' in my_dict)		  # Output: True
print('city' in my_dict)  		# Output: False
# Out:
# {'a': 1, 'b': 3, 'c': 4}
# name: Alice
# age: 25
# True
# False

# %% [markdown]
# 1 .Create a list of 5 integers. Replace the 3rd element with a new value, add two more elements, and remove the last element.

# %%
number =["1","2","3","4","5"]
print(number)
number[2]=2
print(number)
number.append(6)
number.append(7)
print(number)
number.pop()
print(number)
# Out:
# ['1', '2', '3', '4', '5']
# ['1', '2', 2, '4', '5']
# ['1', '2', 2, '4', '5', 6, 7]
# ['1', '2', 2, '4', '5', 6]

# %% [markdown]
# 2. Create a dictionary to store information about a book (title, author, price). Update the price, add a publication year, and then delete the author.

# %%
book ={"title":"My Book","author":"Nazmul","price":"150"}
print(book)
book["price"]
book["year"]="2024"
print(book)
del book["author"]
print(book)
# Out:
# {'title': 'My Book', 'author': 'Nazmul', 'price': '150'}
# {'title': 'My Book', 'author': 'Nazmul', 'price': '150', 'year': '2024'}
# {'title': 'My Book', 'price': '150', 'year': '2024'}

# %% [markdown]
# 3. Write a Python program to merge two dictionaries and handle any duplicate keys.

# %%
dict1 = {'a': 1, 'b': 2}
dict2 = {'b': 3, 'c': 4}
dict1.update(dict2)
print(dict1)
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %% [markdown]
# 4. Write a Python program to sort a list of numbers and remove duplicates.

# %%
number = ["1","2","3","4","5","2"]
numbers = set(number)
print(numbers)
sorted_numbers=sorted(numbers)
print(sorted_numbers)
# Out:
# {'2', '3', '1', '5', '4'}
# ['1', '2', '3', '4', '5']

# %% [markdown]
# # String

# %% [markdown]
# ### 1. String Input Methods

# %%
#Basic Input
#Prompt the user to enter their full name and display it.
name = input("Enter your full name: ")
print("You entered:", name)
#Using strip() to Remove Extra Spaces
#Accept user input with leading/trailing spaces and clean it.
raw_input = input("Enter a word with spaces: ")
clean_input = raw_input.strip()
print("Cleaned input:", clean_input)
#Converting Input to Different Cases
#Prompt for a string and display it in uppercase and lowercase.
text = input("Enter a string: ")
print("Uppercase:", text.upper())
print("Lowercase:", text.lower())
# Out:
# Enter your full name: Nazmul
# You entered: Nazmul
# Enter a word with spaces: Nazmul Hasan
# Cleaned input: Nazmul Hasan
# Enter a string: NaZmul HasaN
# Uppercase: NAZMUL HASAN
# Lowercase: nazmul hasan

# %% [markdown]
# ### String Manipulation

# %%
#Concatenation
#Combine two strings entered by the user.
first = input("Enter the first string: ")
second = input("Enter the second string: ")
result = first + " " + second
print("Concatenated string:", result)

#String Slicing
#Extract specific portions of a string.
text = input("Enter a sentence: ")
print("First 5 characters:", text[:5])
print("Last 5 characters:", text[-5:])
print("Characters from index 2 to 6:", text[2:7])

#Replacing Substrings
#Replace a specific word in a sentence.
sentence = input("Enter a sentence: ")
modified = sentence.replace("bad", "good")
print("Modified sentence:", modified)

#Reversing a String
text = input("Enter a string: ")
reversed_text = text[::-1]
print("Reversed string:", reversed_text)

# %% [markdown]
# ## Built-in String Functions

# %%
#len()
#Find the length of a string.
text = input("Enter a string: ")
print("Length of the string:", len(text))

#split() and join()
#Split a string into words and join them back.
sentence = input("Enter a sentence: ")
words = sentence.split()
print("List of words:", words)
joined_sentence = " ".join(words)
print("Joined back:", joined_sentence)

#startswith() and endswith()
#Check if a string starts or ends with a specific substring.
text = input("Enter a string: ")
print("Starts with 'Hello':", text.startswith("Hello"))
print("Ends with 'world':", text.endswith("world"))

#count()
#Count occurrences of a specific character or substring.
text = input("Enter a string: ")
char = input("Enter a character to count: ")
print(f"The character '{char}' occurs {text.count(char)} times.")

#find() and index()
#Locate a substring in a string.
text = input("Enter a string: ")
word = input("Enter a word to find: ")
print(f"'{word}' found at index:", text.find(word))

#isalpha(), isdigit(), isalnum()
#Validate string content.
text = input("Enter a string: ")
print("Contains only letters:", text.isalpha())
print("Contains only digits:", text.isdigit())
print("Contains only alphanumeric characters:", text.isalnum())

#capitalize(), title(), and swapcase()
#Modify string case styles.
text = input("Enter a sentence: ")
print("Capitalized:", text.capitalize())
print("Title Case:", text.title())
print("Swap Case:", text.swapcase())
# Out:
# Enter a string: Nazmu
# Length of the string: 5
# Enter a sentence: Nazmul is a good boy
# List of words: ['Nazmul', 'is', 'a', 'good', 'boy']
# Joined back: Nazmul is a good boy
# Enter a string: Nazmul Hasan
# Starts with 'Hello': False
# Ends with 'world': False
# Enter a string: Nazmul
# Enter a character to count: 3
# The character '3' occurs 0 times.
# Enter a string: fdg
# Enter a word to find: htfyg
# 'htfyg' found at index: -1
# Enter a string: dtfyh
# Contains only letters: True
# Contains only digits: False
# Contains only alphanumeric characters: True
# Enter a sentence: yfgjh
# Capitalized: Yfgjh
# Title Case: Yfgjh
# Swap Case: YFGJH

# %% [markdown]
# **Optional**

# %%
#Palindrome Checker
#Write a program to check if a given string is a palindrome.
text = input("Enter a string: ")
if text == text[::-1]:
    print("The string is a palindrome.")
else:
    print("The string is not a palindrome.")
#Word Frequency Counter
#Count the frequency of each word in a given sentence.
sentence = input("Enter a sentence: ")
words = sentence.split()
frequency = {word: words.count(word) for word in set(words)}
print("Word frequencies:", frequency)
#Anagram Checker
#Check if two strings are anagrams of each other.
str1 = input("Enter the first string: ")
str2 = input("Enter the second string: ")
if sorted(str1) == sorted(str2):
    print("The strings are anagrams.")
else:
    print("The strings are not anagrams.")
# Out:
# Enter a string: nazan
# The string is a palindrome.
# Enter a sentence: hi i am nayeem . hi i am
# Word frequencies: {'.': 1, 'nayeem': 1, 'i': 2, 'am': 2, 'hi': 2}
# Enter the first string: acb
# Enter the second string: bac
# The strings are anagrams.
