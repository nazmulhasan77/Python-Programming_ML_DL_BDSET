# %%
if True :
    print("I am true")
else :
    print("I am False")
# Out:
# I am true

# %% [markdown]
# 2. Write a program to convert temperature from Centigrade (C’) to Fahrenheit (F’)
# Far=1.8Cel+32

# %%
Celcius = float(input("Enter temp in celcius"))
farenhight = Celcius*1.8+32
print(f"{Celcius} Celcius is {farenhight}")
# Out:
# Enter temp in celcius-45.6
# -45.6 Celcius is -50.08

# %% [markdown]
# 3. Write a program that asks the user to enter a whole number of inches and convert that length to feet and inches. See the following figure. The program should use both integer division and the modulus operator.
#
# Examples: Enter number of Inches: 185
# 185 inches if 15 feet and 5 inches

# %%
inches =int(input("Enter number in inches"))
feet = int(inches/12)
remaining_inchis = inches%12
print(f"{inches} inches is {feet} feet and {remaining_inches} inches.")
# Out:
# Enter number in inches456
# 456 inches is 38 feet and 6 inches.

# %% [markdown]
# Calclute electricy bill ?
# Meter Rent 10
# Input unit used
#
# 1-75 : 5 tk
# 76-125 : 7 tk
# 126-175 : 10 tk
# 176 ++ :  12 tk

# %%
unit=float(input("Enter Meter unit: "))
meter_cost= 10
if unit >= 1 and unit <=75:
  bill=unit*5
elif unit >= 76 and unit <= 125:
  bill=unit*7
bill=meter_cost+bill
print(f"{bill}")
# Out:
# Enter Meter unit5
# 35.0

# %% [markdown]
# 5. A calendar year divisible by four is a leap year, with the exception of the years ending in 00 (that is, those divisible by 100) and not divisible by 400. For instance the years 1600 and 2000 are leap years, but 1700, 1800, and 1900 are not.
#
# Write a program that requests a year as input and states whether it is a leap year.

# %%
year = int(input("Input year "))


if (year%400 ==0):
  print(f"{year} leap year")
elif (year%4==0 and year %100 !=0):
  print(f"{year} is leap year")
else:
  print("Not leap year")
# Out:
# Input year 4156
# 4156 is leap year
