# %%
from google.colab import files
files.upload()

# %%
import pandas as pd

# %%
df=pd.read_csv('Screen Time Data.csv')
df

# %%
df.shape
# Out:
# (28, 12)

# %%
row,col=df.shape

# %%
row
# Out:
# 28

# %%
df.info()

# %% [markdown]
# Working with specfic columns

# %%
df.columns
# Out:
# Index(['index', 'Date', 'Week Day', 'Total Screen Time ', 'Social Networking',
#        'Reading and Reference', 'Other', 'Productivity', 'Health and Fitness',
#        'Entertainment', 'Creativity', 'Yoga'],
#       dtype='object')

# %%
df['Total Screen Time ']

# %%
df['Total Screen Time '].min()
# Out:
# 52

# %%
df['Total Screen Time '].max()
# Out:
# 198

# %%
df['Total Screen Time '].median() #used in neumerical data
# Out:
# 111.0

# %%
df['Total Screen Time '].mean() #used in neumerical data
# Out:
# 113.25

# %%
df['Week Day'].mode() #used in catarogical data

# %%
#standard deviation
df['Total Screen Time '].std()
# Out:
# 43.562322320164775

# %% [markdown]
# A quantile is a statistical term that refers to the division of a dataset into equal parts. Quantiles help you understand the distribution of data by breaking it into intervals where a specific percentage of the data falls below a given value.

# %%
df['Total Screen Time '].quantile(.25)
# Out:
# 83.5

# %%
df['Total Screen Time '].sort_values(ascending=False)

# %%
df.describe()

# %%
df.head(2)
# Out:
#    index      Date   Week Day  Total Screen Time   Social Networking  \
# 0      0  04/17/19  Wednesday                 187                 89
# 1      1  04/18/19   Thursday                 123                 78
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 0                     17     41            22                   0
# 1                     17      8             9                   0
#
#    Entertainment  Creativity  Yoga
# 0              0           0     0
# 1              0           0     0

# %%
df.tail(4)

# %%
df[2:5]
# Out:
#    index      Date  Week Day  Total Screen Time   Social Networking  \
# 2      2  04/19/19    Friday                 112                 52
# 3      3  04/20/19  Saturday                 101                 69
# 4      4  04/21/19    Sunday                  56                 35
#
#    Reading and Reference  Other  Productivity  Health and Fitness  \
# 2                     40      8             4                   0
# 3                      9     38             2                   0
# 4                      2     43             3                   0
#
#    Entertainment  Creativity  Yoga
# 2              3           0     0
# 3              3           0     0
# 4              1           1     0

# %% [markdown]
# Copy

# %%
df_copy=df.copy()
df_copy

# %% [markdown]
# Update

# %%
df['Total Screen Time '].sort_values(ascending=False,inplace=True)
